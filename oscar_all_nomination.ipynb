# %%
# %matplotlib inline

import numpy as np
from sklearn.linear_model import LinearRegression

import pandas as pd
import matplotlib.pyplot as plt

# Make the graphs a bit prettier, and bigger
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (15, 5)

# %%
df_all_nominated = pd.read_csv('./data/oscar_all_nominations.csv', skipinitialspace=True)
df_all_winners = pd.read_csv('./data/oscar_age.csv', skipinitialspace=True)

# %%
df_all_nominated
# Out:
#        year                                           category  winner  \
# 0      1927                                              ACTOR   False
# 1      1927                                              ACTOR    True
# 2      1927                                            ACTRESS   False
# 3      1927                                            ACTRESS    True
# 4      1927                                            ACTRESS   False
# ...     ...                                                ...     ...
# 11053  2017  SCIENTIFIC AND TECHNICAL AWARD (Scientific and...    True
# 11054  2017  SCIENTIFIC AND TECHNICAL AWARD (Technical Achi...    True
# 11055  2017  SCIENTIFIC AND TECHNICAL AWARD (Technical Achi...    True
# 11056  2017  SCIENTIFIC AND TECHNICAL AWARD (Technical Achi...    True
# 11057  2017  SCIENTIFIC AND TECHNICAL AWARD (Technical Achi...    True
#
#                                                   entity
# 0                                    Richard Barthelmess
# ...

# %%
df_all_winners
# Out:
#      year  age               name  \
# 0    1927   22       Janet Gaynor
# 1    1927   44      Emil Jannings
# 2    1928   41      Warner Baxter
# 3    1928   37      Mary Pickford
# 4    1929   62      George Arliss
# ..    ...  ...                ...
# 187  2020   63  Frances McDormand
# 188  2021   53         Will Smith
# 189  2021   44   Jessica Chastain
# 190  2022   60      Michelle Yeoh
# 191  2022   54     Brendan Fraser
#
#                                                  movie gender
# 0    Seventh Heaven, Street Angel and Sunrise: A So...      f
# 1    Seventh Heaven, Street Angel and Sunrise: A So...      m
# 2                                             Coquette      m
# 3                                             Coquette      f
# 4                                         The Divorcee      m
# ..                                                 ...    ...
# 187                                          Nomadland      f
# ...

# %%
merged_data = pd.merge(df_all_nominated, df_all_winners, left_on=['entity', 'category'], right_on=['name', 'category'], how='left')

# Enregistrer le résultat fusionné dans un nouveau fichier CSV
merged_data.to_csv('merged_data.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6224\36343578.py in ?()
# ----> 1 merged_data = pd.merge(df_all_nominated, df_all_winners, left_on=['entity', 'category'], right_on=['name', 'category'], how='left')
#       2
#       3 # Enregistrer le résultat fusionné dans un nouveau fichier CSV
#       4 merged_data.to_csv('merged_data.csv', index=False)
#
# c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     144     copy: bool | None = None,
#     145     indicator: str | bool = False,
#     146     validate: str | None = None,
#     147 ) -> DataFrame:
# --> 148     op = _MergeOperation(
#     149         left,
#     150         right,
#     151         how=how,
#
# ...
